# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("mercedes.csv")

# %%
df
# Out:
#                                            Name     Mileage  Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0
# ...                                         ...         ...     ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC  54,422 mi.     NaN
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.     4.5
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.     4.9
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.     4.8
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.     4.5
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# 3             752   $58,587
# ...

# %%
df.head(10)
# Out:
#                                         Name     Mileage  Rating Review Count  \
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1          2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2          2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8          752
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0        1,502
# 5    2022 Mercedes-Benz AMG E 53 Base 4MATIC   3,573 mi.     4.7        1,239
# 6          2022 Mercedes-Benz AMG SL 63 Base   1,254 mi.     4.7        1,239
# 7     2023 Mercedes-Benz GLE 350 Base 4MATIC  23,071 mi.     3.2           98
# 8                2021 Mercedes-Benz AMG GT C  15,755 mi.     4.8          902
# 9  2023 Mercedes-Benz AMG CLA 45 Base 4MATIC   2,910 mi.     4.5          344
#
#        Price
# 0   $30,900
# 1  $139,999
# 2  $132,999
# 3   $58,587
# 4   $95,990
# 5   $74,999
# 6  $130,999
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Mileage', 'Rating', 'Review Count', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=2429, step=1)

# %%
df["Name"]
# Out:
# 0         2021 Mercedes-Benz A-Class A 220 4MATIC
# 1               2022 Mercedes-Benz AMG SL 63 Base
# 2               2022 Mercedes-Benz AMG SL 63 Base
# 3         2020 Mercedes-Benz AMG E 53 Base 4MATIC
# 4       2021 Mercedes-Benz AMG GLS 63 Base 4MATIC
#                           ...
# 2424      2021 Mercedes-Benz E-Class E 450 4MATIC
# 2425            2022 Mercedes-Benz S-Class 4MATIC
# 2426       2021 Mercedes-Benz GLB 250 Base 4MATIC
# 2427      2023 Mercedes-Benz E-Class E 450 4MATIC
# 2428              2023 Mercedes-Benz GLA 250 Base
# Name: Name, Length: 2429, dtype: object

# %%
df.Name
# Out:
# 0         2021 Mercedes-Benz A-Class A 220 4MATIC
# 1               2022 Mercedes-Benz AMG SL 63 Base
# 2               2022 Mercedes-Benz AMG SL 63 Base
# 3         2020 Mercedes-Benz AMG E 53 Base 4MATIC
# 4       2021 Mercedes-Benz AMG GLS 63 Base 4MATIC
#                           ...
# 2424      2021 Mercedes-Benz E-Class E 450 4MATIC
# 2425            2022 Mercedes-Benz S-Class 4MATIC
# 2426       2021 Mercedes-Benz GLB 250 Base 4MATIC
# 2427      2023 Mercedes-Benz E-Class E 450 4MATIC
# 2428              2023 Mercedes-Benz GLA 250 Base
# Name: Name, Length: 2429, dtype: object

# %%
df[["Name","Price"]]
# Out:
#                                            Name      Price
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC   $30,900
# 1             2022 Mercedes-Benz AMG SL 63 Base  $139,999
# 2             2022 Mercedes-Benz AMG SL 63 Base  $132,999
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC   $58,587
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC   $95,990
# ...                                         ...        ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC   $53,490
# 2425          2022 Mercedes-Benz S-Class 4MATIC   $89,599
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC   $32,890
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   $53,983
# 2428            2023 Mercedes-Benz GLA 250 Base   $46,035
#
# [2429 rows x 2 columns]

# %%
df["Name"]
# Out:
# 0         2021 Mercedes-Benz A-Class A 220 4MATIC
# 1               2022 Mercedes-Benz AMG SL 63 Base
# 2               2022 Mercedes-Benz AMG SL 63 Base
# 3         2020 Mercedes-Benz AMG E 53 Base 4MATIC
# 4       2021 Mercedes-Benz AMG GLS 63 Base 4MATIC
#                           ...
# 2424      2021 Mercedes-Benz E-Class E 450 4MATIC
# 2425            2022 Mercedes-Benz S-Class 4MATIC
# 2426       2021 Mercedes-Benz GLB 250 Base 4MATIC
# 2427      2023 Mercedes-Benz E-Class E 450 4MATIC
# 2428              2023 Mercedes-Benz GLA 250 Base
# Name: Name, Length: 2429, dtype: object

# %%
names= df["Name"]

# %%
names
# Out:
# 0         2021 Mercedes-Benz A-Class A 220 4MATIC
# 1               2022 Mercedes-Benz AMG SL 63 Base
# 2               2022 Mercedes-Benz AMG SL 63 Base
# 3         2020 Mercedes-Benz AMG E 53 Base 4MATIC
# 4       2021 Mercedes-Benz AMG GLS 63 Base 4MATIC
#                           ...
# 2424      2021 Mercedes-Benz E-Class E 450 4MATIC
# 2425            2022 Mercedes-Benz S-Class 4MATIC
# 2426       2021 Mercedes-Benz GLB 250 Base 4MATIC
# 2427      2023 Mercedes-Benz E-Class E 450 4MATIC
# 2428              2023 Mercedes-Benz GLA 250 Base
# Name: Name, Length: 2429, dtype: object

# %%
names[0]
# Out:
# '2021 Mercedes-Benz A-Class A 220 4MATIC'

# %%
names[1:4]
# Out:
# 1          2022 Mercedes-Benz AMG SL 63 Base
# 2          2022 Mercedes-Benz AMG SL 63 Base
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC
# Name: Name, dtype: object

# %%
names[[1,2,4]]
# Out:
# 1            2022 Mercedes-Benz AMG SL 63 Base
# 2            2022 Mercedes-Benz AMG SL 63 Base
# 4    2021 Mercedes-Benz AMG GLS 63 Base 4MATIC
# Name: Name, dtype: object

# %%
first_name= df.loc[0, "Name"]

# %%
first_name
# Out:
# '2021 Mercedes-Benz A-Class A 220 4MATIC'

# %%
first_row = df.loc[0,:]

# %%
first_row
# Out:
# Name            2021 Mercedes-Benz A-Class A 220 4MATIC
# Mileage                                      29,636 mi.
# Rating                                              3.9
# Review Count                                      1,800
# Price                                          $30,900
# Name: 0, dtype: object

# %%
slice_one =df.loc[0:2, "Name" : "Review Count"]

# %%
slice_one
# Out:
#                                       Name     Mileage  Rating Review Count
# 0  2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1        2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2        2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239

# %%
slice_two = df.loc[[0,2,3], ["Name","Review Count"]]

# %%
slice_two
# Out:
#                                       Name Review Count
# 0  2021 Mercedes-Benz A-Class A 220 4MATIC        1,800
# 2        2022 Mercedes-Benz AMG SL 63 Base        1,239
# 3  2020 Mercedes-Benz AMG E 53 Base 4MATIC          752

# %%
df.Rating.mean()
# Out:
# 4.533723653395785

# %%
avg_Rating=df.Rating.mean()

# %%
avg_Rating
# Out:
# 4.533723653395785

# %%
Rating =df["Rating"].max()

# %%
Rating
# Out:
# 5.0

# %%
summary_df=df.describe()

# %%
summary_df
# Out:
#             Rating
# count  2135.000000
# mean      4.533724
# std       0.386506
# min       2.100000
# 25%       4.400000
# 50%       4.600000
# 75%       4.800000
# max       5.000000

# %%
summary_df=df.describe()

# %%
summary_df[["Rating"]]
# Out:
#             Rating
# count  2135.000000
# mean      4.533724
# std       0.386506
# min       2.100000
# 25%       4.400000
# 50%       4.600000
# 75%       4.800000
# max       5.000000

# %%
df["Price"].value_counts()
# Out:
# Price
# $41,990     9
# $46,900     7
# $43,777     7
# $48,000     7
# $49,988     6
#            ..
# $47,308     1
# $47,305     1
# $42,574     1
# $38,599     1
# $46,035     1
# Name: count, Length: 1941, dtype: int64

# %%
df["Price"].unique()
# Out:
# array(['$30,900 ', '$139,999 ', '$132,999 ', ..., '$89,599 ', '$32,890 ',
#        '$46,035 '], dtype=object)

# %%
unique_values=df["Price"].unique()

# %%
unique_values[0]
# Out:
# '$30,900 '

# %%
len(unique_values)
# Out:
# 1941

# %%
df.shape
# Out:
# (2429, 5)

# %%
df.dtypes
# Out:
# Name             object
# Mileage          object
# Rating          float64
# Review Count     object
# Price            object
# dtype: object

# %%
df.head()
# Out:
#                                         Name     Mileage  Rating Review Count  \
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1          2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2          2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8          752
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0        1,502
#
#        Price
# 0   $30,900
# 1  $139,999
# 2  $132,999
# 3   $58,587
# 4   $95,990

# %%
df["Rating"].mean()
# Out:
# 4.533723653395785

# %%
df["new_column"]=1

# %%
df.head()
# Out:
#                                         Name     Mileage  Rating Review Count  \
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1          2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2          2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8          752
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0        1,502
#
#        Price  new_column
# 0   $30,900            1
# 1  $139,999            1
# 2  $132,999            1
# 3   $58,587            1
# 4   $95,990            1

# %%
df["Rating_Percentage"]=df["Rating"]/36

# %%
df.head()
# Out:
#                                         Name     Mileage  Rating Review Count  \
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1          2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2          2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8          752
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0        1,502
#
#        Price  new_column  Rating_Percentage
# 0   $30,900            1           0.108333
# 1  $139,999            1           0.130556
# 2  $132,999            1           0.130556
# 3   $58,587            1           0.133333
# 4   $95,990            1           0.138889

# %%
del df["Rating_Percentage"]

# %%
df.head()
# Out:
#                                         Name     Mileage  Rating Review Count  \
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9        1,800
# 1          2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7        1,239
# 2          2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7        1,239
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8          752
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0        1,502
#
#        Price  new_column
# 0   $30,900            1
# 1  $139,999            1
# 2  $132,999            1
# 3   $58,587            1
# 4   $95,990            1

# %%
df.drop(["new_column","Review Count"], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                         Name  Rating      Price
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900
# 1          2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999
# 2          2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990

# %%
df["new_column"]=1

# %%
df.head()
# Out:
#                                         Name  Rating      Price  new_column
# 0    2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900            1
# 1          2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999            1
# 2          2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999            1
# 3    2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587            1
# 4  2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990            1

# %%
df.drop("new_column", axis=1, inplace=True)

# %%
df
# Out:
#                                            Name  Rating      Price
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900
# 1             2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999
# 2             2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990
# ...                                         ...     ...        ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN   $53,490
# 2425          2022 Mercedes-Benz S-Class 4MATIC     4.5   $89,599
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC     4.9   $32,890
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC     4.8   $53,983
# 2428            2023 Mercedes-Benz GLA 250 Base     4.5   $46,035
#
# [2429 rows x 3 columns]

# %%
df["new_column"]=1

# %%
df
# Out:
#                                            Name  Rating      Price  new_column
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900            1
# 1             2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999            1
# 2             2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999            1
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587            1
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990            1
# ...                                         ...     ...        ...         ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN   $53,490            1
# 2425          2022 Mercedes-Benz S-Class 4MATIC     4.5   $89,599            1
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC     4.9   $32,890            1
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC     4.8   $53,983            1
# 2428            2023 Mercedes-Benz GLA 250 Base     4.5   $46,035            1
#
# [2429 rows x 4 columns]

# %%
df.drop("new_column", axis=1, inplace=False)
# Out:
#                                            Name  Rating      Price
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900
# 1             2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999
# 2             2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990
# ...                                         ...     ...        ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN   $53,490
# 2425          2022 Mercedes-Benz S-Class 4MATIC     4.5   $89,599
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC     4.9   $32,890
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC     4.8   $53,983
# 2428            2023 Mercedes-Benz GLA 250 Base     4.5   $46,035
#
# [2429 rows x 3 columns]

# %%
df
# Out:
#                                            Name  Rating      Price  new_column
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC     3.9   $30,900            1
# 1             2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999            1
# 2             2022 Mercedes-Benz AMG SL 63 Base     4.7  $132,999            1
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587            1
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990            1
# ...                                         ...     ...        ...         ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN   $53,490            1
# 2425          2022 Mercedes-Benz S-Class 4MATIC     4.5   $89,599            1
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC     4.9   $32,890            1
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC     4.8   $53,983            1
# 2428            2023 Mercedes-Benz GLA 250 Base     4.5   $46,035            1
#
# [2429 rows x 4 columns]

# %%
df.drop([0,2], axis=0, inplace=False)
# Out:
#                                            Name  Rating      Price  new_column
# 1             2022 Mercedes-Benz AMG SL 63 Base     4.7  $139,999            1
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC     4.8   $58,587            1
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC     5.0   $95,990            1
# 5       2022 Mercedes-Benz AMG E 53 Base 4MATIC     4.7   $74,999            1
# 6             2022 Mercedes-Benz AMG SL 63 Base     4.7  $130,999            1
# ...                                         ...     ...        ...         ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN   $53,490            1
# 2425          2022 Mercedes-Benz S-Class 4MATIC     4.5   $89,599            1
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC     4.9   $32,890            1
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC     4.8   $53,983            1
# 2428            2023 Mercedes-Benz GLA 250 Base     4.5   $46,035            1
#
# [2427 rows x 4 columns]

# %%
df.sort_values(by = "Rating", inplace=True, ascending=True)

# %%
df.head()
# Out:
#                                     Name  Rating     Price  new_column
# 1910     2023 Mercedes-Benz GLB 250 Base     2.1  $44,990            1
# 1882     2021 Mercedes-Benz GLB 250 Base     2.1  $32,190            1
# 1448      2018 Mercedes-Benz AMG GT Base     2.1  $79,990            1
# 392   2023 Mercedes-Benz AMG GLA 35 Base     2.5  $44,999            1
# 1420  2022 Mercedes-Benz AMG GLA 45 Base     2.5  $46,098            1

# %%
df.sort_values(by=["Rating", "new_column"], inplace=True, ascending=[True, True])

# %%
df.head()
# Out:
#                                     Name  Rating     Price  new_column
# 1910     2023 Mercedes-Benz GLB 250 Base     2.1  $44,990            1
# 1882     2021 Mercedes-Benz GLB 250 Base     2.1  $32,190            1
# 1448      2018 Mercedes-Benz AMG GT Base     2.1  $79,990            1
# 392   2023 Mercedes-Benz AMG GLA 35 Base     2.5  $44,999            1
# 1420  2022 Mercedes-Benz AMG GLA 45 Base     2.5  $46,098            1

# %%
df_mercedes = pd.read_csv("mercedes.csv", index_col=0)

# %%
df.head()
# Out:
#                                     Name  Rating     Price  new_column
# 1910     2023 Mercedes-Benz GLB 250 Base     2.1  $44,990            1
# 1882     2021 Mercedes-Benz GLB 250 Base     2.1  $32,190            1
# 1448      2018 Mercedes-Benz AMG GT Base     2.1  $79,990            1
# 392   2023 Mercedes-Benz AMG GLA 35 Base     2.5  $44,999            1
# 1420  2022 Mercedes-Benz AMG GLA 45 Base     2.5  $46,098            1

# %%
df.dtypes
# Out:
# Name           object
# Rating        float64
# Price          object
# new_column      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Name', 'Rating', 'Price', 'new_column'], dtype='object')

# %%
df.rename(columns={"Price":"Approx_Price"},inplace=False)
# Out:
#                                            Name  Rating Approx_Price  \
# 1910            2023 Mercedes-Benz GLB 250 Base     2.1     $44,990
# 1882            2021 Mercedes-Benz GLB 250 Base     2.1     $32,190
# 1448             2018 Mercedes-Benz AMG GT Base     2.1     $79,990
# 392          2023 Mercedes-Benz AMG GLA 35 Base     2.5     $44,999
# 1420         2022 Mercedes-Benz AMG GLA 45 Base     2.5     $46,098
# ...                                         ...     ...          ...
# 2367                2021 Mercedes-Benz A-Class      NaN     $31,995
# 2369            2021 Mercedes-Benz GLC 300 Base     NaN     $33,850
# 2387  2019 Mercedes-Benz AMG GLC 43 Base 4MATIC     NaN     $40,500
# 2391    2023 Mercedes-Benz G-Class G 550 4MATIC     NaN    $152,986
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC     NaN     $53,490
#
#       new_column
# 1910           1
# 1882           1
# 1448           1
# 392            1
# 1420           1
# ...          ...
# 2367           1
# ...

# %%
df.set_index("Name", inplace=True)

# %%
df.head()
# Out:
#                                     Rating     Price  new_column
# Name
# 2023 Mercedes-Benz GLB 250 Base        2.1  $44,990            1
# 2021 Mercedes-Benz GLB 250 Base        2.1  $32,190            1
# 2018 Mercedes-Benz AMG GT Base         2.1  $79,990            1
# 2023 Mercedes-Benz AMG GLA 35 Base     2.5  $44,999            1
# 2022 Mercedes-Benz AMG GLA 45 Base     2.5  $46,098            1

# %%
df.loc["2023 Mercedes-Benz AMG GLA 35 Base", "Price"]
# Out:
# Name
# 2023 Mercedes-Benz AMG GLA 35 Base    $44,999
# 2023 Mercedes-Benz AMG GLA 35 Base    $50,384
# 2023 Mercedes-Benz AMG GLA 35 Base    $46,417
# Name: Price, dtype: object

# %%
df.set_index("Rating", inplace=False)
# Out:
#             Price  new_column
# Rating
# 2.1      $44,990            1
# 2.1      $32,190            1
# 2.1      $79,990            1
# 2.5      $44,999            1
# 2.5      $46,098            1
# ...           ...         ...
# NaN      $31,995            1
# NaN      $33,850            1
# NaN      $40,500            1
# NaN     $152,986            1
# NaN      $53,490            1
#
# [2429 rows x 2 columns]

# %%
df["Name"]=df.index

# %%
df.set_index("Rating", inplace=True)

# %%
df.head()
# Out:
#            Price  new_column                                Name
# Rating
# 2.1     $44,990            1     2023 Mercedes-Benz GLB 250 Base
# 2.1     $32,190            1     2021 Mercedes-Benz GLB 250 Base
# 2.1     $79,990            1      2018 Mercedes-Benz AMG GT Base
# 2.5     $44,999            1  2023 Mercedes-Benz AMG GLA 35 Base
# 2.5     $46,098            1  2022 Mercedes-Benz AMG GLA 45 Base

# %%
df.reset_index(drop=False, inplace=True)

# %%
df.head()
# Out:
#    Rating     Price  new_column                                Name
# 0     2.1  $44,990            1     2023 Mercedes-Benz GLB 250 Base
# 1     2.1  $32,190            1     2021 Mercedes-Benz GLB 250 Base
# 2     2.1  $79,990            1      2018 Mercedes-Benz AMG GT Base
# 3     2.5  $44,999            1  2023 Mercedes-Benz AMG GLA 35 Base
# 4     2.5  $46,098            1  2022 Mercedes-Benz AMG GLA 45 Base

# %%
df_missing=pd.read_csv("mercedes.csv",na_values=["NaN", "not available"])

# %%
df_missing
# Out:
#                                            Name     Mileage  Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0
# ...                                         ...         ...     ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC  54,422 mi.     NaN
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.     4.5
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.     4.9
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.     4.8
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.     4.5
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# 3             752   $58,587
# ...

# %%
df_missing=pd.read_csv("mercedes.csv",na_values={"Rating" : "not available", "Mileage": -1})

# %%
df.head()
# Out:
#    Rating     Price  new_column                                Name
# 0     2.1  $44,990            1     2023 Mercedes-Benz GLB 250 Base
# 1     2.1  $32,190            1     2021 Mercedes-Benz GLB 250 Base
# 2     2.1  $79,990            1      2018 Mercedes-Benz AMG GT Base
# 3     2.5  $44,999            1  2023 Mercedes-Benz AMG GLA 35 Base
# 4     2.5  $46,098            1  2022 Mercedes-Benz AMG GLA 45 Base

# %%
df_missing=pd.read_csv("mercedes.csv", na_values=["NaN","not available"])

# %%
df_missing
# Out:
#                                            Name     Mileage  Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0
# ...                                         ...         ...     ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC  54,422 mi.     NaN
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.     4.5
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.     4.9
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.     4.8
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.     4.5
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# 3             752   $58,587
# ...

# %%
df.isnull()
# Out:
#       Rating  Price  new_column   Name
# 0      False  False       False  False
# 1      False  False       False  False
# 2      False  False       False  False
# 3      False  False       False  False
# 4      False  False       False  False
# ...      ...    ...         ...    ...
# 2424    True  False       False  False
# 2425    True  False       False  False
# 2426    True  False       False  False
# 2427    True  False       False  False
# 2428    True  False       False  False
#
# [2429 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Rating        294
# Price           0
# new_column      0
# Name            0
# dtype: int64

# %%
df_missing.dropna(axis=0, inplace=False)
# Out:
#                                            Name     Mileage  Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0
# ...                                         ...         ...     ...
# 2423          2020 Mercedes-Benz AMG GT 53 Base  36,814 mi.     4.7
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.     4.5
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.     4.9
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.     4.8
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.     4.5
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# 3             752   $58,587
# ...

# %%
df_missing.fillna(0, inplace=False)
# Out:
#                                            Name     Mileage  Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.     3.9
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.     4.7
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.     4.7
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.     4.8
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.     5.0
# ...                                         ...         ...     ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC  54,422 mi.     0.0
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.     4.5
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.     4.9
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.     4.8
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.     4.5
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# 3             752   $58,587
# ...

# %%
mean_Rating=df_missing.Rating.mean()

# %%
df_missing.fillna({'Rating': mean_Rating}, inplace=False)
# Out:
#                                            Name     Mileage    Rating  \
# 0       2021 Mercedes-Benz A-Class A 220 4MATIC  29,636 mi.  3.900000
# 1             2022 Mercedes-Benz AMG SL 63 Base   5,540 mi.  4.700000
# 2             2022 Mercedes-Benz AMG SL 63 Base   4,890 mi.  4.700000
# 3       2020 Mercedes-Benz AMG E 53 Base 4MATIC  29,746 mi.  4.800000
# 4     2021 Mercedes-Benz AMG GLS 63 Base 4MATIC  32,631 mi.  5.000000
# ...                                         ...         ...       ...
# 2424    2021 Mercedes-Benz E-Class E 450 4MATIC  54,422 mi.  4.533724
# 2425          2022 Mercedes-Benz S-Class 4MATIC  11,395 mi.  4.500000
# 2426     2021 Mercedes-Benz GLB 250 Base 4MATIC  30,392 mi.  4.900000
# 2427    2023 Mercedes-Benz E-Class E 450 4MATIC   3,413 mi.  4.800000
# 2428            2023 Mercedes-Benz GLA 250 Base   6,336 mi.  4.500000
#
#      Review Count      Price
# 0           1,800   $30,900
# 1           1,239  $139,999
# 2           1,239  $132,999
# ...
